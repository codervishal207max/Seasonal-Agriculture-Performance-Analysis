# %% [markdown]
# <a href="https://colab.research.google.com/github/codervishal207max/Seasonal-Agriculture-Performance-Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
#1. Load Datasets
data = pd.read_csv('/content/seasonal_agriculture_performance_dataset.csv')

# %%
data.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
data.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %%
#2. Data Exploration & Shape
print("Rows:",data.shape[0])
print("Columns:",data.shape[1])
# Out:
# Rows: 4000
# Columns: 28

# %%
print("\n----- Columns Names -------")

print(data.columns)
# Out:
# ----- Columns Names -------
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %%
print("\n---- Data Info ----")
print(data.info())
# Out:
# ---- Data Info ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
print("\n---- Statistical Summery ----")
print(data.describe(include='all'))
# Out:
# ---- Statistical Summery ----
#         Farm_ID           State  District  Crop  Season  Farm_Area_Hectares  \
# count      4000            4000      4000  4000    4000         4000.000000
# unique     4000               8        10     8       3                 NaN
# top     SF13961  Andhra Pradesh  Ludhiana  Rice  Kharif                 NaN
# freq          1             529       427   690    1779                 NaN
# mean        NaN             NaN       NaN   NaN     NaN            7.888265
# std         NaN             NaN       NaN   NaN     NaN            4.223764
# min         NaN             NaN       NaN   NaN     NaN            0.500000
# 25%         NaN             NaN       NaN   NaN     NaN            4.260000
# 50%         NaN             NaN       NaN   NaN     NaN            7.895000
# 75%         NaN             NaN       NaN   NaN     NaN           11.650000
# max         NaN             NaN       NaN   NaN     NaN           15.000000
#
# ...

# %%
# Check Missing Value & Duplicates
print("\n------ Missing Values Before Cleaning -----")
print(data.isnull().sum())
print("Duplicate Rows:", data.duplicated().sum())
# Out:
# ------ Missing Values Before Cleaning -----
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# ...

# %%
#3. Data Cleaning
data1 = data.drop_duplicates()

# Handle Missing Values for Numerical columns
numeric_cols = data1.select_dtypes(include=np.number).columns
data1[numeric_cols] = data1[numeric_cols].fillna(data1[numeric_cols].median())

# Handle Missing values fr Categorical Columns
categorical_cols = data1.select_dtypes(include='object').columns
for col in categorical_cols:
  data1[col] = data1[col].fillna(data1[col].mode()[0])

# Check Missing Value & Duplicates After Cleaning
print("\n------ Missing Values After Cleaning -----")
print(data1.isnull().sum())
print("Duplicate Rows:", data1.duplicated().sum())
# Out:
# ------ Missing Values After Cleaning -----
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# ...

# %%
#4. Seasonal Yield Analysis
season_yield = data.groupby('Season')['Yield_Tonnes_Ha'].mean()
print("\n--- Average Yield by Season ---")
print(season_yield)

plt.figure(figsize=(8,5))
sns.barplot(x=season_yield.index, y=season_yield.values, palette='viridis')
plt.title('Average Agriculture yield by Season')
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.show()
# Out:
# --- Average Yield by Season ---
# Season
# Kharif    5.643973
# Rabi      5.080498
# Zaid      4.665942
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
#5. Total Prduction by Season
season_production = data.groupby('Season')['Production_Tonnes'].sum()
print("\n----- Total Production by Season -----")
print(season_production)


plt.figure(figsize=(8,5))
sns.barplot(x=season_production.index, y=season_production.values, palette='magma')
plt.title("Total Agriculture Production by Season")
plt.xlabel("Season")
plt.ylabel("Total Prduction(Tonnes)")
plt.show()
# Out:
# ----- Total Production by Season -----
# Season
# Kharif    82387.61
# Rabi      67498.88
# Zaid      23098.35
# Name: Production_Tonnes, dtype: float64

# %%
#6. Crop vs Season Analysis (Pivot Table & Heatnap)

crop_season = pd.pivot_table(data, values='Yield_Tonnes_Ha', index='Crop', columns='Season', aggfunc='mean')
print("\n----- Crop vs Season Pivot Tables -----")
print(crop_season)

plt.figure(figsize=(8,5))
sns.heatmap(crop_season, annot=True,fmt=".2f",cmap="YlGn")
plt.title("Average Crop Yield Across Season")
plt.show()
# Out:
# ----- Crop vs Season Pivot Tables -----
# Season        Kharif       Rabi       Zaid
# Crop
# Chilli      1.731413   1.461615   1.177742
# Cotton      1.372804   1.192915   0.951648
# Groundnut   1.483646   1.221445   1.037778
# Maize       2.966410   2.614913   2.297590
# Pulses      1.036063   0.871887   0.652131
# Rice        2.707621   2.333680   1.900490
# Sugarcane  53.459120  43.940394  38.423922
# Wheat       2.255430   2.058814   1.748588

# %%
# 7. Environmental Conditions vs Yield Correlation
corr_cols = ['Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Yield_Tonnes_Ha']
correlation = data[corr_cols].corr()
print("\n--- Correlation Matrix ---")
print(correlation)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Between Environmental Factors and Yield")
plt.show()
# Out:
# --- Correlation Matrix ---
#                    Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm           1.000000           0.200020      0.523966
# Avg_Temperature_C     0.200020           1.000000      0.138136
# Humidity_pct          0.523966           0.138136      1.000000
# Yield_Tonnes_Ha       0.030853           0.009349      0.011277
#
#                    Yield_Tonnes_Ha
# Rainfall_mm               0.030853
# Avg_Temperature_C         0.009349
# Humidity_pct              0.011277
# Yield_Tonnes_Ha           1.000000

# %%
# 8. Scatter Plots: Rainfall & Temperature vs Yield
plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='Rainfall_mm', y='Yield_Tonnes_Ha', hue='Season', alpha=0.7)
plt.title("Rainfall vs Agricultural Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()


plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='Avg_Temperature_C', y='Yield_Tonnes_Ha', hue='Season', alpha=0.7)
plt.title("Temperature vs Agricultural Yield")
plt.xlabel("Avg Temperature (°C)")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %%
# 9. Resource Usage Across Seasons (Fertilizer)
fertilizer_season = data.groupby('Season')['Fertilizer_kg_ha'].mean()
print("\n--- Average Fertilizer Usage by Season ---")
print(fertilizer_season)

plt.figure(figsize=(8, 5))
sns.barplot(x=fertilizer_season.index, y=fertilizer_season.values, palette='crest')
plt.title("Average Fertilizer Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Fertilizer Usage (kg/ha)")
plt.show()
# Out:
# --- Average Fertilizer Usage by Season ---
# Season
# Kharif    187.077965
# Rabi      185.407068
# Zaid      184.638047
# Name: Fertilizer_kg_ha, dtype: float64

# %%
# 10. Statistical Analysis (T-Test between Kharif and Rabi Yields)
season1 = data[data['Season'] == 'Kharif']['Yield_Tonnes_Ha']
season2 = data[data['Season'] == 'Rabi']['Yield_Tonnes_Ha']
t_stat, p_value = stats.ttest_ind(season1, season2, equal_var=False)
print("\n--- T-Test Results (Kharif vs Rabi Yields) ---")
print("T-statistic:", t_stat)
print("P-value:", p_value)

if p_value < 0.05:
    print("Result: The difference in yield between Kharif and Rabi is statistically significant.")
else:
    print("Result: The difference in yield between Kharif and Rabi is not statistically significant.")
# Out:
# --- T-Test Results (Kharif vs Rabi Yields) ---
# T-statistic: nan
# P-value: nan
# Result: The difference in yield between Kharif and Rabi is not statistically significant.

# %%
# 11. Outlier Detection (Boxplot)
plt.figure(figsize=(8, 5))
sns.boxplot(data=data, x='Season', y='Yield_Tonnes_Ha', palette='Set2')
plt.title("Yield Distribution and Outliers Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes/Ha)")
plt.show()

# %%
# 12. Final Summary Table
summary_of_data = data.groupby('Season').agg({
    'Yield_Tonnes_Ha': 'mean',
    'Production_Tonnes': 'sum',
    'Rainfall_mm': 'mean',
    'Avg_Temperature_C': 'mean'
}).reset_index()

print("\n--- Final Summary Table ---")
print(summary_of_data)
# Out:
# --- Final Summary Table ---
#    Season  Yield_Tonnes_Ha  Production_Tonnes  Rainfall_mm  Avg_Temperature_C
# 0  Kharif         5.643973           82387.61   852.084205          28.454019
# 1    Rabi         5.080498           67498.88   436.000124          23.489183
# 2    Zaid         4.665942           23098.35   299.421784          31.042088
